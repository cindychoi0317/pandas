# %%
import pandas as pd
import numpy as np

# %%
apt =pd.read_excel('C:\\GitHub\\test\\apt_Archive1\\apt_sell_all.xlsx')
apt.head()
# Out:
#    Unnamed: 0   city town village            name  size  price_sold  floor  \
# 0           0  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      160000      2
# 1           1  서울특별시  강남구     개포동  개포2차현대아파트(220)    77      149500      4
# 2           2  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      155000      4
# 3           3  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      157000      2
# 4           4  서울특별시  강남구     개포동  개포6차우성아파트1동~8동    79      151500      5
#
#    year_built    yy  mm  dd zipcode  address
# 0        1988  2019  11  18   655-2  언주로 103
# 1        1988  2020   6  23   655-2  언주로 103
# 2        1987  2019   8  28   658-1    언주로 3
# 3        1987  2019   9   2   658-1    언주로 3
# 4        1987  2019   9  10   658-1    언주로 3

# %%
jg_under85 = apt[(apt['town'] == '중구') & (apt['yy'] == 2020) & (apt['price_sold'] <= 85000)]
jg_under85
# Out:
#        Unnamed: 0   city town village        name  size  price_sold  floor  \
# 93905       93905  서울특별시   중구   남산동2가       남산퍼시픽    80       48000      1
# 93906       93906  서울특별시   중구   남산동2가       남산퍼시픽   108       81500      5
# 93919       93919  서울특별시   중구   만리동1가       대우디오빌    73       70000     15
# 93920       93920  서울특별시   중구   만리동1가       대우디오빌    73       74000     12
# 93921       93921  서울특별시   중구   만리동1가       대우디오빌    73       75000     14
# ...           ...    ...  ...     ...         ...   ...         ...    ...
# 95116       95116  서울특별시   중구     흥인동  동대문 와이즈 캐슬    15       17300      9
# 95117       95117  서울특별시   중구     흥인동  동대문 와이즈 캐슬    15       17000      8
# 95118       95118  서울특별시   중구     흥인동  동대문 와이즈 캐슬    15       16900     11
# 95119       95119  서울특별시   중구     흥인동  동대문 와이즈 캐슬    15       17000     14
# 95120       95120  서울특별시   중구     흥인동      동대문솔하임    17       24000     18
#
#        year_built    yy  mm  dd zipcode     address
# ...

# %%
jg_under85.to_excel('C:\\GitHub\\test\\apt_Archive1\\jg_under85.xlsx')

# %%
mpg_under85 = apt[(apt['town'] == '마포구') & (apt['yy'] == 2020) & (apt['price_sold'] <= 85000)]
mpg_under85
# Out:
#        Unnamed: 0   city town village     name  size  price_sold  floor  \
# 53505       53505  서울특별시  마포구     공덕동   공덕헤리지움    29       40050     12
# 53506       53506  서울특별시  마포구     공덕동   공덕헤리지움    17       23500     12
# 53507       53507  서울특별시  마포구     공덕동   공덕헤리지움    37       51000     12
# 53508       53508  서울특별시  마포구     공덕동   공덕헤리지움    29       40750     13
# 53509       53509  서울특별시  마포구     공덕동   공덕헤리지움    29       40050     13
# ...           ...    ...  ...     ...      ...   ...         ...    ...
# 56768       56768  서울특별시  마포구     합정동  합정한강아파트    52       51800      7
# 56793       56793  서울특별시  마포구     현석동  강변힐스테이트    59       82000      4
# 56794       56794  서울특별시  마포구     현석동  강변힐스테이트    59       84200      5
# 56859       56859  서울특별시  마포구     현석동  밤섬힐스테이트    59       69000      1
# 56860       56860  서울특별시  마포구     현석동  밤섬힐스테이트    59       84000     10
#
#        year_built    yy  mm  dd zipcode   address
# 53505        2020  2020   7  23  108-57   만리재로 96
# ...

# %%
mpg_under85.to_excel('C:\\GitHub\\test\\apt_Archive1\\mpg_under85.xlsx')
